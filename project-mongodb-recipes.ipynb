# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <div style="text-align: left;"><img src="images/logo-simple-framed-green-gradient.svg" style="display: inline-block; width: 100px; height: 100px;" /></div>
#     <span style="font-size: 24px; color: green; line-height: 100px;">Spoonacular API</span>
# </div>

# %% [markdown]
# <div style="width: 600px; height: 100px;"></div>

# %% [markdown]
# # APIculinary: Cooking Up Insights with Spoonacular Data

# %% [markdown]
# <div style="width: 600px; height: 10px;"></div>

# %% [markdown]
# ![](images/ontology2.svg)

# %% [markdown]
# <div style="width: 600px; height: 100px;"></div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item">
#   <li><span><a href="#Summary" data-toc-modified-id="Summary-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Summary</a></span></li>
#   <li><span><a href="#Requirements-&amp;-Configuration" data-toc-modified-id="Requirements-&amp;-Configuration-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Requirements &amp; Configuration</a></span>
#     <ul class="toc-item">
#       <li><span><a href="#Spoonacular-API-Documentation-and-Authentication" data-toc-modified-id="Spoonacular-API-Documentation-and-Authentication-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Spoonacular API Documentation and Authentication</a></span></li>
#       <li><span><a href="#Global-Configuration" data-toc-modified-id="Global-Configuration-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Global Configuration</a></span></li>
#     </ul>
#   </li>
#   <li><span><a href="#ELT-Process" data-toc-modified-id="ELT-Process-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>ELT Process</a></span>
#     <ul class="toc-item">
#       <li><span><a href="#DB-Setup" data-toc-modified-id="DB-Setup-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>DB Setup</a></span></li>
#       <li><span><a href="#Extract" data-toc-modified-id="Extract-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Extract</a></span></li>
#       <li><span><a href="#Load" data-toc-modified-id="Load-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Load</a></span></li>
#       <li><span><a href="#Transform" data-toc-modified-id="Transform-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Transform</a></span></li>
#       <li><span><a href="#Datastructure" data-toc-modified-id="Datastructure-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Datastructure</a></span></li>
#       <li><span><a href="#Data-Quality-Checks" data-toc-modified-id="Data-Quality-Checks-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Data Quality Checks</a></span>
#         <ul class="toc-item">
#           <li><span><a href="#Checking-and-Removing-Duplicate-Recipes" data-toc-modified-id="Checking-and-Removing-Duplicate-Recipes-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Checking and Removing Duplicate Recipes</a></span></li>
#           <li><span><a href="#Checking-Missing-Values" data-toc-modified-id="Checking-Missing-Values-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Checking Missing Values</a></span></li>
#         </ul>
#       </li>
#     </ul>
#   </li>
#   <li><span><a href="#Data-Analysis" data-toc-modified-id="Data-Analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Analysis</a></span>
#     <ul class="toc-item">
#       <li><span><a href="#Number-of-Recipes-by-Cuisines" data-toc-modified-id="Number-of-Recipes-by-Cuisines-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Number of Recipes by Cuisines</a></span></li>
#       <li><span><a href="#Top-20-Ingredients" data-toc-modified-id="Top-20-Ingredients-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Top-20-Ingredients</a></span></li>
#       <li><span><a href="#Top-20-Equipments" data-toc-modified-id="Top-20-Equipments-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Top 20 Equipments</a></span></li>
#       <li><span><a href="#Top-5-Longest-Recipe-Names" data-toc-modified-id="Top-5-Longest-Recipe Names-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Top 5 Longest Recipe Names</a></span></li>
#       <li><span><a href="#Ranking-Source-Websites" data-toc-modified-id="Ranking-Source-Websites-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Ranking Source Websites</a></span></li>
#       <li><span><a href="#Analysis-of-Dietary-Categories-by-Cuisine" data-toc-modified-id="Analysis-of-Dietary-Categories-by-Cuisine-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Analysis of Dietary Categories by Cuisine</a></span></li>
#       <li><span><a href="#Top-10-Dish-Categories-in-the-Database" data-toc-modified-id="Top-10-Dish-Categories-in-the-Database-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Top 10 Dish Categories in the Database</a></span></li>
#       <li><span><a href="#Analysis-of-Preparation-Time" data-toc-modified-id="Analysis-of-Preparation-Timee-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Analysis of Preparation Time</a></span></li>
#     </ul>
#   </li>
#   <li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Conclusion</a></span></li>
#   <li><span><a href="#Learnings" data-toc-modified-id="Learnings-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Learnings</a></span></li>
# </ul></div>

# %% [markdown]
# <div style="width: 600px; height: 850px;"></div>

# %% [markdown]
# ## Summary

# %% [markdown]
# In a world filled with culinary wonders and gastronomic delights, the intersection of data and food has never been more fascinating. Our project, embarks on a journey to explore the vast realm of culinary data through the lens of Spoonacular's API.
#
# So, prepare your apron, sharpen your data skills, and get ready to unlock the secrets of the culinary world with "APIculinary: Cooking Up Insights with Spoonacular Data." Together, we'll cook up a data-driven feast that tantalizes both the palate and the mind. Bon appétit!

# %% [markdown]
# ## Requirements & Configuration

# %%
! pip3 list | findstr "pymongo dnspython pandas"
# Out:
# dnspython                         2.4.2
# pandas                            2.1.1
# pymongo                           4.5.0

# %%
import pymongo
import pprint as pp
import pandas as pd
import requests
import json
import time
import string
from IPython.display import HTML,display, Image
import matplotlib.pyplot as plt
import os
#import config2

# %%
# pandas configuration
# Configure Pandas options
pd.set_option('display.precision', 2)
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_colwidth', 50)

# Use pd.describe_option() to see descriptions
#pd.describe_option('display.precision')
#pd.describe_option('display.max_rows')
#pd.describe_option('display.max_colwidth')

# %% [markdown]
# ### Spoonacular API Documentation and Authentication

# %% [markdown]
# For using the API an API key is needed, which can be obtained with free registration on the below website:
# https://spoonacular.com/food-api/console#Profile
#
# The Key need to be embedded in the code with each requets as follow:  **?apiKey=YOUR-API-KEY**
# There are daily rates to be considered using the free acounts with a personal API key.

# %%
# download/search recipes with different cuisine tags iterating trough on the cuisine list found on webpage 
# and store them in a list: https://spoonacular.com/food-api/docs#Cuisines

cuisine_list = ["african", "asian", "american","british","cajun","caribbean","chinese","eastern,european","european","french",
                "german","greek","indian","irish","italian","japanese","jewish","korean","latin,american","mediterranean",
                "mexican","middle,eastern","nordic","southern","spanish","thai","vietnamese"]

api_key = "fc74932e3dbd4f17903e795e8989fbb5"
num = 1
API_URL = "https://api.spoonacular.com/recipes/random?apiKey="+api_key+"&tags="+cuisine_list[0]+"&number="+str(num)

# %% [markdown]
# ### Global Configuration

# %% [markdown]
# One of the below option to be chosen depending on whether we use local host or the atlas webserver.

# %%
# create database on atlas webserver
#username = "user"
#password = "password"
#CNX_STR = "mongodb+srv://"+username+":"+password+"@cluster0.fwnjbfw.mongodb.net"

# %%
# create database on local host
CNX_STR = "localhost:27017"
DB_NAME = "spoonacular_final"
COLL_NAME = "recipes"

# %%
#Link to placholder image where image missing
placeholder = 'https://images.unsplash.com/photo-1676364242733-3dbe7fdbd425'

# %% [markdown]
# ## ELT Process

# %% [markdown]
# ### DB Setup

# %%
# connection to MongoDB
client = pymongo.MongoClient(CNX_STR)
db = client[DB_NAME]
recipes = db[COLL_NAME]

# %%
# Remove all existing documents
recipes.drop()
recipes.count_documents({})
# Out:
# 0

# %% [markdown]
# ###  Extract

# %%
# download italian recipes 
url = API_URL  # API is filtered by cuisine = italian + for 1 recipe
r = requests.get(url)
data = r.json()

# %%
# inspect first recipe
recipe = data['recipes'][0]
recipe
# Out:
# {'vegetarian': False,
#  'vegan': False,
#  'glutenFree': True,
#  'dairyFree': True,
#  'veryHealthy': False,
#  'cheap': False,
#  'veryPopular': True,
#  'sustainable': False,
#  'lowFodmap': False,
#  'weightWatcherSmartPoints': 13,
#  'gaps': 'no',
#  'preparationMinutes': -1,
#  'cookingMinutes': -1,
#  'aggregateLikes': 347,
#  'healthScore': 14,
#  'creditsText': 'Afrolems',
#  'license': 'CC BY 4.0',
#  'sourceName': 'Afrolems',
#  'pricePerServing': 124.81,
#  'extendedIngredients': [{'id': 2004,
#    'aisle': 'Produce',
#    'image': 'bay-leaves.jpg',
#    'consistency': 'SOLID',
#    'name': 'bay leaves',
#    'nameClean': 'bay leaves',
#    'original': '2 Bay leaves',
#    'originalName': 'Bay leaves',
#    'amount': 2.0,
#    'unit': '',
#    'meta': [],
#    'measures': {'us': {'amount': 2.0, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 2.0, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 2015,
#    'aisle': 'Spices and Seasonings',
# ...

# %%
# hide fields with None values
for key in list(recipe.keys()):
    if recipe[key] is None:
        del recipe[key]
recipe
# Out:
# {'vegetarian': False,
#  'vegan': False,
#  'glutenFree': True,
#  'dairyFree': True,
#  'veryHealthy': False,
#  'cheap': False,
#  'veryPopular': True,
#  'sustainable': False,
#  'lowFodmap': False,
#  'weightWatcherSmartPoints': 13,
#  'gaps': 'no',
#  'preparationMinutes': -1,
#  'cookingMinutes': -1,
#  'aggregateLikes': 347,
#  'healthScore': 14,
#  'creditsText': 'Afrolems',
#  'license': 'CC BY 4.0',
#  'sourceName': 'Afrolems',
#  'pricePerServing': 124.81,
#  'extendedIngredients': [{'id': 2004,
#    'aisle': 'Produce',
#    'image': 'bay-leaves.jpg',
#    'consistency': 'SOLID',
#    'name': 'bay leaves',
#    'nameClean': 'bay leaves',
#    'original': '2 Bay leaves',
#    'originalName': 'Bay leaves',
#    'amount': 2.0,
#    'unit': '',
#    'meta': [],
#    'measures': {'us': {'amount': 2.0, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 2.0, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 2015,
#    'aisle': 'Spices and Seasonings',
# ...

# %%
# extract values from single recipe
def extract_values(recipe):
    values = {
        'id': int(recipe['id']),
        'name': recipe['title'],
        'category': recipe['dishTypes'],
        'prepTime': int(recipe['readyInMinutes']),
        'source': recipe['sourceUrl'],
        'diets': recipe['diets'],
        'vegan': recipe['vegan'],
        'vegetarian': recipe['vegetarian'],
        'glutenFree': recipe['glutenFree'],
        'dairyFree': recipe['dairyFree'],
        'veryHealthy': recipe['veryHealthy'],
        'cuisines': recipe['cuisines'],
        'ingredients': [],
        'equipment': [],
    }
    if 'image' in recipe:
        values['image'] = recipe['image']
    else:
        values['image'] = placeholder

    if 'extendedIngredients' in recipe:
        ingredients_list = recipe['extendedIngredients']
        ingredient_names = [ingredient.get('name', '') for ingredient in ingredients_list]
        values['ingredients'] = ingredient_names
    
    if 'analyzedInstructions' in recipe:
        instructions = recipe['analyzedInstructions']
        for instruction in instructions:
            equipment_list = []
            for step in instruction.get('steps', []):
                equipment_list.extend([item['name'] for item in step.get('equipment', [])])
            values['equipment'].extend(equipment_list)
            
    return values

# %%
# test extraction for one recipe
doc = extract_values(recipe)
doc
# Out:
# {'id': 716298,
#  'name': 'How to Make Party Jollof Rice',
#  'category': ['antipasti',
#   'starter',
#   'snack',
#   'appetizer',
#   'antipasto',
#   "hor d'oeuvre"],
#  'prepTime': 45,
#  'source': 'http://www.afrolems.com/2012/11/23/how-to-make-party-jollof-rice/',
#  'diets': ['gluten free', 'dairy free'],
#  'vegan': False,
#  'vegetarian': False,
#  'glutenFree': True,
#  'dairyFree': True,
#  'veryHealthy': False,
#  'cuisines': ['African'],
#  'ingredients': ['bay leaves',
#   'curry powder',
#   'garlic',
#   'cubes of maggi',
#   'bulb of onion',
#   'pepper',
#   'rice',
#   'roma tomatoes',
#   'salt',
#   'scotch bonnet peppers',
#   'scotch bonnet peppers',
#   'thyme',
#   'can of tomato puree',
#   'cooking spoons of vegetable oil',
#   'water'],
#  'equipment': ['bowl', 'pot', 'pot'],
#  'image': 'https://spoonacular.com/recipeImages/716298-556x370.jpg'}

# %% [markdown]
# <div style="width: 600px; height: 200px;"></div>

# %%
# our random API allows max downoad of 100 random recipes at a time
# API is filtered by cuisine

list_recipes = []
num = 100

for i in range(0,len(cuisine_list)):
    # download recipes 
    url = "https://api.spoonacular.com/recipes/random?apiKey="+api_key+"&tags="+cuisine_list[i]+"&number="+str(num)
    r = requests.get(url)
    data = r.json()

    #add recipes to the list
    if data['recipes'] is not None:
        for recipe in data['recipes']:
            values = extract_values(recipe)
            list_recipes.append(values)

# %%
nr = len(list_recipes)
nr
# Out:
# 849

# %%
# inspect last recipe:
list_recipes[nr-1]
# Out:
# {'id': 664830,
#  'name': 'Vietnamese Beef-Noodle Soup With Asian Greens, Okay Vietnamese/japanese',
#  'category': ['lunch', 'soup', 'main course', 'main dish', 'dinner'],
#  'prepTime': 45,
#  'source': 'http://www.foodista.com/recipe/T42QJSJN/vietnamese-beef-noodle-soup-with-asian-greens-okay-vietnamesejapanese',
#  'diets': ['dairy free'],
#  'vegan': False,
#  'vegetarian': False,
#  'glutenFree': False,
#  'dairyFree': True,
#  'veryHealthy': False,
#  'cuisines': ['Vietnamese', 'Asian'],
#  'ingredients': ['baby bok choy leaves',
#   'brown sugar',
#   'brown sugar',
#   'cardamom pods',
#   'fish sauce',
#   'basil leaves',
#   'basil leaves',
#   'bean sprouts',
#   'ginger',
#   'mint leaves',
#   'garlic cloves',
#   'less-sodium beef broth',
#   'lime wedges',
#   'less-sodium soy sauce',
#   'miso',
#   'wide rice stick noodles',
#   'wide rice stick noodles',
#   'sesame oil',
#   'sirloin steak',
#   'snow peas',
#   'star anise',
#   'thai chile',
#   'water',
# ...

# %% [markdown]
# <div style="width: 600px; height: 450px;"></div>

# %% [markdown]
# ### Load

# %%
# insert the list of recipes(=documents) into MongoDB collection "recipes"
recipes.insert_many(list_recipes);

# %%
# count number of documents inserted
recipes.count_documents({})
# Out:
# 849

# %%
# get one drink from MongoDB
recipes.find_one()
# Out:
# {'_id': ObjectId('65440c484699a0ab6ad09647'),
#  'id': 716298,
#  'name': 'How to Make Party Jollof Rice',
#  'category': ['antipasti',
#   'starter',
#   'snack',
#   'appetizer',
#   'antipasto',
#   "hor d'oeuvre"],
#  'prepTime': 45,
#  'source': 'http://www.afrolems.com/2012/11/23/how-to-make-party-jollof-rice/',
#  'diets': ['gluten free', 'dairy free'],
#  'vegan': False,
#  'vegetarian': False,
#  'glutenFree': True,
#  'dairyFree': True,
#  'veryHealthy': False,
#  'cuisines': ['African'],
#  'ingredients': ['bay leaves',
#   'curry powder',
#   'garlic',
#   'cubes of maggi',
#   'bulb of onion',
#   'pepper',
#   'rice',
#   'roma tomatoes',
#   'salt',
#   'scotch bonnet peppers',
#   'scotch bonnet peppers',
#   'thyme',
#   'can of tomato puree',
#   'cooking spoons of vegetable oil',
#   'water'],
#  'equipment': ['bowl', 'pot', 'pot'],
#  'image': 'https://spoonacular.com/recipeImages/716298-556x370.jpg'}

# %%
# get 5 recipes from MongoDB and display as datframe
r = recipes.aggregate([
      {"$limit": 5}])
pd.DataFrame(r)
# Out:
#                         _id      id  \
# 0  65440c484699a0ab6ad09647  716298
# 1  65440c484699a0ab6ad09648  716268
# 2  65440c484699a0ab6ad09649  644167
# 3  65440c484699a0ab6ad0964a  631748
# 4  65440c484699a0ab6ad0964b  663824
#
#                                                 name  \
# 0                      How to Make Party Jollof Rice
# 1                        African Chicken Peanut Stew
# 2  Garam Masala Pork Chops with Mint Yogurt and S...
# 3                              Asian Shrimp Stir-Fry
# 4                   Trinidadian Chicken Potato Curry
#
#                                             category  prepTime  \
# 0  [antipasti, starter, snack, appetizer, antipas...        45
# 1      [lunch, soup, main course, main dish, dinner]        45
# 2            [lunch, main course, main dish, dinner]        45
# 3            [lunch, main course, main dish, dinner]        45
# 4            [lunch, main course, main dish, dinner]        45
#
# ...

# %% [markdown]
# <div style="width: 600px; height: 10px;"></div>

# %% [markdown]
# ### Transform

# %%
# check document structure
r = recipes.aggregate([
    {"$project": {"_id": 0}},
    {"$limit": 5}])
pd.DataFrame(r)
# Out:
#        id                                               name  \
# 0  716298                      How to Make Party Jollof Rice
# 1  716268                        African Chicken Peanut Stew
# 2  644167  Garam Masala Pork Chops with Mint Yogurt and S...
# 3  631748                              Asian Shrimp Stir-Fry
# 4  663824                   Trinidadian Chicken Potato Curry
#
#                                             category  prepTime  \
# 0  [antipasti, starter, snack, appetizer, antipas...        45
# 1      [lunch, soup, main course, main dish, dinner]        45
# 2            [lunch, main course, main dish, dinner]        45
# 3            [lunch, main course, main dish, dinner]        45
# 4            [lunch, main course, main dish, dinner]        45
#
#                                               source  \
# 0  http://www.afrolems.com/2012/11/23/how-to-make...
# 1  http://www.afrolems.com/2014/03/18/african-chi...
# ...

# %%
# add fields "ingredients_cnt","equipment_cnt" and "display_image" to collection
r = recipes.aggregate([
    {"$addFields": {"ingredients_cnt": { "$size": "$ingredients"}}},
    {"$addFields": {"equipment_cnt": { "$size": "$equipment"}}},
    {"$addFields": {"display_image": {"$concat": 
                                      ["<a href=", "$image", " target='_blank'><img src=", "$image", " width='150' height='150'></a>"]}}},
    {"$out": "recipes"}])

# %%
# check document structure
r = recipes.aggregate([
    {"$project": {"_id": 0,"source":0,"image":0,"vegan":0,"vegetarian":0,"glutenFree":0,"dairyFree":0}},
    {"$limit": 5}])
pd.DataFrame(r)
# Out:
#        id                                               name  \
# 0  716298                      How to Make Party Jollof Rice
# 1  716268                        African Chicken Peanut Stew
# 2  644167  Garam Masala Pork Chops with Mint Yogurt and S...
# 3  631748                              Asian Shrimp Stir-Fry
# 4  663824                   Trinidadian Chicken Potato Curry
#
#                                             category  prepTime  \
# 0  [antipasti, starter, snack, appetizer, antipas...        45
# 1      [lunch, soup, main course, main dish, dinner]        45
# 2            [lunch, main course, main dish, dinner]        45
# 3            [lunch, main course, main dish, dinner]        45
# 4            [lunch, main course, main dish, dinner]        45
#
#                                             diets  veryHealthy  \
# 0                       [gluten free, dairy free]        False
# 1                       [gluten free, dairy free]         True
# ...

# %% [markdown]
# <div style="width: 600px; height: 20px;"></div>

# %% [markdown]
# ### Datastructure

# %% [markdown]
# <img src="images/data_structure2.svg" style="height:400px;">
#
#
# We have the below UML Class Relationships in our database:
#
# - Recipe  }o--|{ Category   : has > \n < is assigned to
# - Recipe  }o--|{ Diet       : associated with > \n < is assigned to
# - Recipe  }|--|{ Cuisine    : associated with > \n < is assigned to
# - Recipe  }o--|{ Ingredient : needs > \n < are used
# - Recipe  }o--|{ Equipment  : needs > \n < are used
#
#
# **Relationships with examples explained:**
# **}o--|{**: one recipe has zero or multiple categories one category can be assigned to multiple recipes
# **}o--|{**: one recipe has zero or multiple diets one diet can be assigned to multiple recipes
# **}|--|{**: one recipe could have one or multiple cuisines and each cuisine can be assigned to multiple recipes
# **||--||**: each recipe shall have a source and one souce url is assigned to one recipe
# **|o--o|**: a diet can have zero or one vegan category, a vegan category can be assigned to zero or one time to diet

# %% [markdown]
# <div style="width: 600px; height: 700px;"></div>

# %% [markdown]
# ### Data Quality Checks

# %% [markdown]
# Before delving into further analysis of our dataset, it is imperative to conduct elementary data quality assessments, focusing on the identification of duplicate records and the presence of missing values. This chapter is dedicated to executing these crucial quality checks on our database, ensuring the integrity and reliability of our data for subsequent analysis.

# %% [markdown]
# <div style="width: 600px; height: 50px;"></div>

# %% [markdown]
# #### Checking and Removing Duplicate Recipes

# %% [markdown]
# Considering that our API provides a random assortment of recipes, it is anticipated that our database may contain duplicate entries. This arises from recipes being associated with multiple cuisine labels. In these instances, we may come across one or two duplicate recipes.
#
# As we move forward, our focus will be on identifying these duplicates based on recipe IDs and subsequently removing them to ensure data integrity. This process will streamline our dataset for more effective analysis.

# %%
# finding duplicate recipes
for d in recipes.find():
    print(d)
print()

pipeline = [
 {"$group": {
         "_id": {"id": "$id"} ,
         "count": { "$sum" : 1 }}},
 {"$match": {
         "count": { "$gt": 1 }}}]
# Out:
# {'_id': ObjectId('65440c484699a0ab6ad09647'), 'id': 716298, 'name': 'How to Make Party Jollof Rice', 'category': ['antipasti', 'starter', 'snack', 'appetizer', 'antipasto', "hor d'oeuvre"], 'prepTime': 45, 'source': 'http://www.afrolems.com/2012/11/23/how-to-make-party-jollof-rice/', 'diets': ['gluten free', 'dairy free'], 'vegan': False, 'vegetarian': False, 'glutenFree': True, 'dairyFree': True, 'veryHealthy': False, 'cuisines': ['African'], 'ingredients': ['bay leaves', 'curry powder', 'garlic', 'cubes of maggi', 'bulb of onion', 'pepper', 'rice', 'roma tomatoes', 'salt', 'scotch bonnet peppers', 'scotch bonnet peppers', 'thyme', 'can of tomato puree', 'cooking spoons of vegetable oil', 'water'], 'equipment': ['bowl', 'pot', 'pot'], 'image': 'https://spoonacular.com/recipeImages/716298-556x370.jpg', 'ingredients_cnt': 15, 'equipment_cnt': 3, 'display_image': "<a href=https://spoonacular.com/recipeImages/716298-556x370.jpg target='_blank'><img src=https://spoonacular.com/recipeImag
# ...

# %%
# counting duplicate recipes

for d in recipes.aggregate(pipeline):
    print(d)
print()
# Out:
# {'_id': {'id': 641565}, 'count': 2}
# {'_id': {'id': 663824}, 'count': 2}
# {'_id': {'id': 642138}, 'count': 2}
# {'_id': {'id': 648048}, 'count': 2}
# {'_id': {'id': 647922}, 'count': 3}
# {'_id': {'id': 640730}, 'count': 2}
# {'_id': {'id': 660842}, 'count': 2}
# {'_id': {'id': 641559}, 'count': 2}
# {'_id': {'id': 665778}, 'count': 3}
# {'_id': {'id': 646034}, 'count': 2}
# {'_id': {'id': 665294}, 'count': 3}
# {'_id': {'id': 634710}, 'count': 2}
# {'_id': {'id': 636962}, 'count': 2}
# {'_id': {'id': 636599}, 'count': 2}
# {'_id': {'id': 662264}, 'count': 2}
# {'_id': {'id': 648176}, 'count': 2}
# {'_id': {'id': 660709}, 'count': 2}
# {'_id': {'id': 648479}, 'count': 2}
# {'_id': {'id': 636970}, 'count': 2}
# {'_id': {'id': 638642}, 'count': 2}
# {'_id': {'id': 655400}, 'count': 2}
# {'_id': {'id': 649137}, 'count': 2}
# {'_id': {'id': 652354}, 'count': 2}
# {'_id': {'id': 664553}, 'count': 2}
# {'_id': {'id': 633884}, 'count': 2}
# {'_id': {'id': 660231}, 'count': 2}
# ...

# %%
# deleting duplicate recipes

pipeline = [
 {"$group": {
         "_id": {"id": "$id"} ,
         "duplicates": { "$addToSet": "$_id" } ,
         "count": { "$sum" : 1 }}},
 {"$match": {
         "count": { "$gt": 1 }}}]

for d in recipes.aggregate(pipeline):
    print(d)
    to_be_deleted = d["duplicates"][1:]  # all exept the first item should be deleted
    recipes.delete_many({
        "_id": {"$in": to_be_deleted}
    })
print()
# Out:
# {'_id': {'id': 641565}, 'duplicates': [ObjectId('65440c484699a0ab6ad09672'), ObjectId('65440c484699a0ab6ad09887')], 'count': 2}
# {'_id': {'id': 663824}, 'duplicates': [ObjectId('65440c484699a0ab6ad097e2'), ObjectId('65440c484699a0ab6ad0964b')], 'count': 2}
# {'_id': {'id': 642138}, 'duplicates': [ObjectId('65440c484699a0ab6ad0966b'), ObjectId('65440c484699a0ab6ad09735')], 'count': 2}
# {'_id': {'id': 648048}, 'duplicates': [ObjectId('65440c484699a0ab6ad098c4'), ObjectId('65440c484699a0ab6ad09834')], 'count': 2}
# {'_id': {'id': 647922}, 'duplicates': [ObjectId('65440c484699a0ab6ad09751'), ObjectId('65440c484699a0ab6ad09863'), ObjectId('65440c484699a0ab6ad098ee')], 'count': 3}
# {'_id': {'id': 640730}, 'duplicates': [ObjectId('65440c484699a0ab6ad097c4'), ObjectId('65440c484699a0ab6ad098e3')], 'count': 2}
# {'_id': {'id': 660842}, 'duplicates': [ObjectId('65440c484699a0ab6ad097de'), ObjectId('65440c484699a0ab6ad097a7')], 'count': 2}
# ...

# %%
# counting duplicate recipes after the deletion duplicates

for d in recipes.aggregate(pipeline):
    print(d)
print()

# %%
# count number of documents after deleting duplicates

recipes.count_documents({})
# Out:
# 562

# %% [markdown]
# <div style="width: 600px; height: 50px;"></div>

# %% [markdown]
# #### Checking Missing Values

# %% [markdown]
# In the following code, we conduct a thorough evaluation to identify any missing values within our dataset. These values are integral to our forthcoming analysis in Chapter 4. This preliminary assessment ensures that our data remains complete and reliable, setting the stage for a comprehensive and robust analysis.

# %%
# find document where field value is None
for d in recipes.find({"$or":[{"id": None},
                              {"name": None},
                              {"category": None},
                              {"prepTime":None},
                              {"source": None},
                              {"diets": None},
                              {"vegan": None},
                              {"vegetarian": None},
                              {"glutenFree": None},
                              {"dairyFree": None},
                              {"veryHealthy": None},
                              {"cuisines": None},
                              {"ingredients": None},
                              {"equipment": None},
                              {"image": None},
                             ]}):
    pprint(d)
print()

# %% [markdown]
# If nothing is printed, which indicates that we do not have any missing values in our database.

# %% [markdown]
# <div style="width: 600px; height: 100px;"></div>

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# In this chapter, we set out to unravel the diverse and captivating world of cuisines. Our mission is to understand not just the number of recipes at our disposal but to uncover the rich tapestry of ingridients, equipments, and cultures that contribute to the global culinary experience. Data analysis is our compass on this journey. By harnessing the power of data, we aim to answer some intriguing questions:
#
# -  How many recipes in our database belong to each cuisine?
# -  Which are most used ingridients and equipments?
# -  Which recipes have the longest name?
# -  Which are the higest represented source webpages in our database?
# -  Which cuisines do offer recipes with diverse dietary restrictions?
# -  Which are the top dish categories in our database?
# -  How long is the preparation time in the recipes?

# %% [markdown]
# <div style="width: 600px; height: 50px;"></div>

# %% [markdown]
# ### Number of Recipes by Cuisines

# %% [markdown]
# This analysis reveals the top 20 cuisines with the highest number of recipes. By focusing on the most popular cuisines, we gain insight into culinary preferences. Additionally, the bar chart provides an overview of the number of recipes for all cuisines, offering a broader perspective on the diversity of culinary traditions represented in the dataset. These visualizations help us better understand the distribution of recipes by cuisine.
#
# Since our cuisine labels encompass both continents and individual countries, it's common for a single recipe to be associated with multiple labels. When reviewing the results below, you'll notice that the broader regions tend to prominently feature in the top 10 list of cuisines.

# %% [markdown]
# <div style="width: 600px; height: 50px;"></div>

# %%
# Showing the top 20 cuisines with number of recipes they are assigned to

r = recipes.aggregate([
    {"$project": {"cuisines": 1}},
    {"$unwind": "$cuisines"},
    {"$group": {"_id": "$cuisines", "count": {"$sum": 1}}},
    {"$project": {"_id": 0, "cuisines": "$_id", "count":1}},
    {"$sort": {"count": -1}},
    {"$limit": 20},
 ])

pd.DataFrame(r)
# Out:
#     count        cuisines
# 0     186        European
# 1     145   Mediterranean
# 2     109           Asian
# 3     103         Italian
# 4     100        American
# 5      68         Mexican
# 6      48        Southern
# 7      40          Indian
# 8      30          French
# 9      24         Chinese
# 10     20  Middle Eastern
# 11     17           Cajun
# 12     17          Creole
# 13     13         English
# 14     13        Scottish
# 15     13         British
# 16     12           Greek
# 17     11          Korean
# 18     10           Irish
# 19      9        Japanese

# %%
# Showing all cuisines with the number of recipes they are assigned to

r = recipes.aggregate([
    {"$project": {"cuisines": 1}},
    {"$unwind": "$cuisines"},
    {"$group": {"_id": "$cuisines", "count": {"$sum": 1}}},
    {"$project": {"_id": 0, "cuisines": "$_id", "count":1}},
    {"$sort": {"count": -1}},
 ])

# Create a bar chart
df=pd.DataFrame(r)

# Set the figure size to make the whole chart wider
fig, ax = plt.subplots(figsize=(10, 6))

# Create a bar chart using the 'cuisines' and 'count' columns
ax.bar(df['cuisines'], df['count'], width=0.8)

# Add count numbers as text labels above each bar
for i, count in enumerate(df['count']):
    ax.text(i, count + 1, str(count), ha='center')

plt.xlabel('Cuisines')
plt.ylabel('Count')
plt.title('Top 10 Cuisines by Recipe Count')
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="width: 600px; height: 500px;"></div>

# %% [markdown]
# ### Top 20 Ingredients

# %% [markdown]
# This analysis presents the top 20 ingredients that are most frequently used across recipes. It offers valuable insights into the essential components of a diverse range of dishes. Additionally, the total number of ingredients used in our database, reveales the complexity and variety of our database.

# %%
# Showing the top 20 ingridients used in our database

r = recipes.aggregate([
    {"$project": {"ingredients": 1}},
    {"$unwind": "$ingredients"},
    {"$group": {"_id": "$ingredients", "count": {"$sum": 1}}},
    {"$project": {"_id": 0, "name": "$_id", "count":1}},
    {"$sort": {"count": -1}},
    {"$limit": 20},])

pd.DataFrame(r)
# Out:
#     count             name
# 0     218             salt
# 1     153            onion
# 2     152           butter
# 3     152           garlic
# 4     129        olive oil
# 5     117            flour
# 6     115      bell pepper
# 7     113            sugar
# 8      96             eggs
# 9      90           pepper
# 10     86            water
# 11     78      brown sugar
# 12     72             milk
# 13     62  salt and pepper
# 14     58         cilantro
# 15     55    baking powder
# 16     52    garlic cloves
# 17     50          parsley
# 18     48              egg
# 19     44        soy sauce

# %%
# Showing the total number of ingridients used in our database

r = recipes.aggregate([
    {"$project": {"ingredients": 1}},
    {"$unwind": "$ingredients"},
    {"$group": {"_id": "$ingredients", "count": {"$sum": 1}}},
    {"$project": {"_id": 0, "name": "$_id", "count":1}},
    {"$sort": {"count": -1}}])
df = pd.DataFrame(r)
num_rows = len(df)
print("Number of rows in all recipes is", num_rows)
# Out:
# Number of rows in all recipes is 1688

# %%
# Changing the width of rows to display full names
pd.set_option('display.max_colwidth', 150)

# Showing the top 5 recipe with the most ingridients used

r = recipes.aggregate([
    {"$project": {"name": 1, "id": 1, "image": 1,"ingredients_cnt": 1, "display_image": 1}},
    {"$project": {"_id": 0, "id": 1, "name": 1,"ingredients_cnt": 1,"display_image": 1}},
    {"$sort": {"ingredients_cnt": -1}},
    {"$limit": 5}])

df=pd.DataFrame(r)

# Display the DataFrame with HTML links and images
display(HTML(df.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>ingredients_cnt</th>
#       <th>display_image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>637935</td>
#       <td>Chicken and Vegetarian Tamales With Red Mole Sauce</td>
#       <td>42</td>
#       <td><a href=https://spoonacular.com/recipeImages/637935-556x370.jpg target='_blank'><img src=https://spoonacular.com/recipeImages/637935-556x370.jpg width='150' height='150'></a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>716217</td>
#       <td>Vietnamese Pancakes with Vegetables, Herbs and a Fragrant Dipping Sauce (Bánh Xèo)</td>
#       <td>28</td>
#       <td><a href=https://spoonacular.com/recipeImages/716217-556x370.jpg target='_blank'><img src=https://spoonacular.com/recipeImages/716217-556x370.jpg width='150' height='150'></a></td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <div style="width: 600px; height: 600px;"></div>

# %% [markdown]
# ### Top 20 Equipments

# %% [markdown]
# This chapter explores the top 20 kitchen equipment items frequently used in our Spoonacular recipe database. These essential tools are the building blocks for the mouthwatering recipes you'll find here.

# %%
# Showing the top 20 equipment used in our database 

r = recipes.aggregate([
    {"$project": {"equipment": 1}},
    {"$unwind": "$equipment"},
    {"$group": {"_id": "$equipment", "count": {"$sum": 1}}},
    {"$project": {"_id": 0, "name": "$_id", "count":1}},
    {"$sort": {"count": -1}},
    {"$limit": 20},
 ])

pd.DataFrame(r)
# Out:
#     count            name
# 0     501            oven
# 1     432      frying pan
# 2     406            bowl
# 3     150             pot
# 4     138           whisk
# 5     112    baking sheet
# 6     111       sauce pan
# 7      72  food processor
# 8      71      baking pan
# 9      71   aluminum foil
# 10     55         blender
# 11     52           grill
# 12     45     mixing bowl
# 13     33           knife
# 14     31    baking paper
# 15     31         spatula
# 16     30    paper towels
# 17     28       wire rack
# 18     25     slow cooker
# 19     24    plastic wrap

# %%
# Showing the total number of equipments used in our database

r = recipes.aggregate([
    {"$project": {"equipment": 1}},
    {"$unwind": "$equipment"},
    {"$group": {"_id": "$equipment", "count": {"$sum": 1}}},
    {"$project": {"_id": 0, "name": "$_id", "count":1}},
    {"$sort": {"count": -1}}])
    #{"$limit": 10} ])

df = pd.DataFrame(r)

# Set the figure size to make the whole chart wider
fig, ax = plt.subplots(figsize=(6, 15))

# Create a bar chart using the 'equipment' and 'count' columns
ax.barh(df['name'], df['count'])

plt.xlabel('Count')
plt.ylabel('Equipment')
plt.title('Equipments used in the database')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility

# Show the plot
plt.tight_layout(pad=3)
plt.show()

# %%
# Showing the top 10 recipe with the most equipments used

r = recipes.aggregate([
    {"$project": {"name": 1, "id": 1, "image": 1,"equipment_cnt": 1,"display_image": 1}},
    {"$project": {"_id": 0, "id": 1, "name": 1,"equipment_cnt": 1,"display_image": 1}},
    {"$sort": {"equipment_cnt": -1}},
    {"$limit": 10}])

df=pd.DataFrame(r)

# Display the DataFrame with HTML links and images
display(HTML(df.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>equipment_cnt</th>
#       <th>display_image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>643471</td>
#       <td>fresh corn, roasted tomato & pickled garlic pizza with cornmeal crust</td>
#       <td>20</td>
#       <td><a href=https://spoonacular.com/recipeImages/643471-556x370.jpg target='_blank'><img src=https://spoonacular.com/recipeImages/643471-556x370.jpg width='150' height='150'></a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>636581</td>
#       <td>Butternut Squash and Zucchini Lasagna-Gluten free, Vegan</td>
#       <td>19</td>
#       <td><a href=https://images.unsplash.com/photo-1676364242733-3dbe7fdbd425 target='_blank'><img src=https://images.unsplash.com/photo-1676364242733-3dbe7fdbd425 width='150' height='150'></a></td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <div style="width: 600px; height: 20px;"></div>

# %% [markdown]
# ### Top 5 Longest Recipe Names

# %% [markdown]
# In this chapter, we explore the dataset of recipes, focusing on the length of recipe names and identifying the top longest recipe names. This analysis allows us to gain insights into the complexity and creativity of recipe naming. We also provide visual representation by including images of the dishes associated with these lengthy recipes.

# %%
# Showing the top 5 recipes with the longest recipe names
r = recipes.aggregate([
    {"$project": {"name": 1, "id": 1, "display_image": 1}},
    {"$addFields": {"length": {"$strLenCP":"$name"}}},
    {"$project": {"_id": 0, "id": 1, "name": 1,"length": 1, "display_image": 1}},
    {"$sort": {"length": -1}},
    {"$limit": 5}])
df=pd.DataFrame(r)

# Display the DataFrame with HTML links and images
display(HTML(df.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>display_image</th>
#       <th>length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>654430</td>
#       <td>Pan Seared Fresh Maine Diver Scallops Creamy Avocado Champagne Grape Salad Teriyaki Cabernet Butter Sauce</td>
#       <td><a href=https://spoonacular.com/recipeImages/654430-556x370.jpg target='_blank'><img src=https://spoonacular.com/recipeImages/654430-556x370.jpg width='150' height='150'></a></td>
#       <td>105</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>654432</td>
#       <td>Pan Seared Lamb Loin With Chimichurri & Roasted Trio Squash Salad With Goat Cheese and Pinenuts</td>
# ...

# %% [markdown]
# <div style="width: 600px; height: 450px;"></div>

# %% [markdown]
# ### Ranking Source Websites

# %% [markdown]
# In this chapter, we delve into the process of extracting and ranking source websites from a collection of diverse URLs in a MongoDB database. Using advanced aggregation techniques, we demonstrate how to effectively extract website names, filtering out prefixes such as 'http://' and 'https://.' We then proceed to rank these websites based on their frequency of occurrence, providing valuable insights into the most prominent sources within the dataset.

# %%
# extracting the name of the website from the source url with regular expression
r = recipes.aggregate([
    {"$project": {"website": {"$regexFindAll": {"input": "$source","regex": "(?<=//)(.*?\\.com)"}}}},
    {"$unwind":"$website"},
    {"$group": {"_id": "$website.match","count": { "$sum": 1 }}},
    {"$project": {"_id": 0,"website": "$_id","count": 1}},
    {"$sort": {"count": -1}}])
pd.DataFrame(r)
# Out:
#    count                        website
# 0    496               www.foodista.com
# 1     34               www.pinkwhen.com
# 2     10               www.afrolems.com
# 3      8  fullbellysisters.blogspot.com
# 4      6                spoonacular.com
# 5      6      foodandspice.blogspot.com
# 6      1    oneperfectbite.blogspot.com
# 7      1             pickfreshfoods.com

# %%
# plotting the resulty in a barchart
r = recipes.aggregate([
    {"$project": {"website": {"$regexFindAll": {"input": "$source","regex": "(?<=//)(.*?\\.com)"}}}},
    {"$unwind":"$website"},
    {"$group": {"_id": "$website.match","count": { "$sum": 1 }}},
    {"$project": {"_id": 0,"website": "$_id","count": 1}},
    {"$sort": {"count": -1}}])
# Create a bar chart
df=pd.DataFrame(r)
# Set the figure size to make the whole chart wider
fig, ax = plt.subplots(figsize=(10, 6))
# Create a bar chart using the 'websites' and 'count' columns
ax.bar(df['website'], df['count'], width=0.8)
# Add count numbers as text labels above each bar
for i, count in enumerate(df['count']):
    ax.text(i, count + 1, str(count), ha='center')
plt.xlabel('Websites')
plt.ylabel('Count')
plt.title('Source websites  of recipes')
plt.xticks(rotation=90)
# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="width: 600px; height: 50px;"></div>

# %% [markdown]
# ### Analysis of Dietary Categories by Cuisine

# %% [markdown]
# In the current phase, we are compiling a comprehensive list of all available diet types within the database. Subsequently, we are constructing a structured data frame to aggregate the number of recipes based on multiple factors, including cuisine, vegan, vegetarian, dairy-free, and gluten-free diets. This aggregation forms the foundation for a visually insightful bar and line chart, where the total count of recipes per cuisine is represented as bars, while the number of dietary categories is depicted as distinct colored lines. This graphical representation not only allows for easy comparison of dietary preferences across cuisines but also provides a dynamic view of the relationship between culinary traditions and dietary choices.

# %%
# listing all diet types available in the database

r = recipes.aggregate([
    {"$project": { "diets":1}},
    {"$unwind": "$diets"},
    {"$group": {"_id": "$diets", "count": {"$sum": 1}}},
    {"$project": {"_id": 0, "diets":1,"name":"$_id", "count":1}},
    {"$sort": {"count": -1}},
 ])

pd.DataFrame(r)
# Out:
#    count                  name
# 0    284           gluten free
# 1    226            dairy free
# 2    184  lacto ovo vegetarian
# 3     73                 vegan
# 4     50                primal
# 5     38           pescatarian
# 6     37              whole 30
# 7     25           paleolithic
# 8     19             ketogenic
# 9     16       fodmap friendly

# %%
# Create data frame with aggregated recipe numbers

r = recipes.aggregate([
    # Unwind the cuisines array
    {"$unwind": "$cuisines"},
        # Group by cuisine and calculate the total count
    {"$group": {
        "_id": "$cuisines",
        "total_ct": {"$sum": 1},
        "vegan_ct": {"$sum": {"$cond": ["$vegan", 1, 0] }},
        "vegetarian_ct": {"$sum": {"$cond": ["$vegetarian", 1, 0] }},
        "dairyFree_ct": {"$sum": {"$cond": ["$dairyFree", 1, 0] }},
        "glutenFree_ct": {"$sum": {"$cond": ["$glutenFree", 1, 0] }}}},
        # Project the result to rename fields and exclude _id
    {"$project": {
        "_id": 0,
        "cuisine": "$_id",
        "total_ct": 1,
        "vegan_ct": 1,
        "vegetarian_ct": 1,
        "dairyFree_ct": 1,
        "glutenFree_ct": 1}},
        # Sort the results by total count in descending order
    {"$sort": {"total_ct": -1}}])
pd.DataFrame(r)
# Out:
#     total_ct  vegan_ct  vegetarian_ct  dairyFree_ct  glutenFree_ct  \
# 0        186         9             54            35             68
# 1        145         8             38            23             52
# 2        109        21             34            82             76
# 3        103         4             18            17             32
# 4        100         7             31            32             35
# ..       ...       ...            ...           ...            ...
# 28         2         0              0             2              1
# 29         2         1              1             2              2
# 30         2         0              0             2              2
# 31         1         0              0             0              0
# 32         1         0              0             0              0
#
#           cuisine
# 0        European
# 1   Mediterranean
# 2           Asian
# 3         Italian
# 4        American
# ..            ...
# 28         Jewish
# ...

# %%
# Plot aggregated table in a bar and line chart showing total count for the cuisines and number of diets as a colored line

r = recipes.aggregate([
    # Unwind the cuisines array
    {"$unwind": "$cuisines"},
    
    # Group by cuisine and calculate the total count
    {"$group": {
        "_id": "$cuisines",
        "total_ct": {"$sum": 1},
        "vegan_ct": {"$sum": {"$cond": ["$vegan", 1, 0] }},
        "vegetarian_ct": {"$sum": {"$cond": ["$vegetarian", 1, 0] }},
        "dairyFree_ct": {"$sum": {"$cond": ["$dairyFree", 1, 0] }},
        "glutenFree_ct": {"$sum": {"$cond": ["$glutenFree", 1, 0] }}}},
    
    # Project the result to rename fields and exclude _id
    {"$project": {
        "_id": 0,
        "cuisine": "$_id",
        "total_ct": 1,
        "vegan_ct": 1,
        "vegetarian_ct": 1,
        "dairyFree_ct": 1,
        "glutenFree_ct": 1}},
    
    # Sort the results by total count in descending order
    {"$sort": {"total_ct": -1}}])

df = pd.DataFrame(r)

# Set the figure size to adjust the plot dimensions
fig, ax = plt.subplots(figsize=(12, 6))

# Create a bar plot for "total_ct"
df.plot(kind="bar", x="cuisine", y="total_ct", ax=ax, label="total_ct")

# Plot lines for other columns
df.plot(kind="line", x="cuisine", y="vegan_ct", ax=ax, label="vegan_ct", secondary_y=True)
df.plot(kind="line", x="cuisine", y="vegetarian_ct", ax=ax, label="vegetarian_ct", secondary_y=True)
df.plot(kind="line", x="cuisine", y="glutenFree_ct", ax=ax, label="glutenFree_ct", secondary_y=True)
df.plot(kind="line", x="cuisine", y="dairyFree_ct", ax=ax, label="dairyFree_ct", secondary_y=True)

# Set labels and title
ax.set_xlabel("Cuisine")
ax.set_ylabel("Total Count (Bars)")
ax.set_title("Number of Dietary Categories by Cuisine")

# Show the legend
# Manually create a custom legend
custom_legend = [
    plt.Line2D([0], [0], color='b', label="vegan_ct"),
    plt.Line2D([0], [0], color='g', label="vegetarian_ct"),
    plt.Line2D([0], [0], color='r', label="glutenFree_ct"),
    plt.Line2D([0], [0], color='y', label="dairyFree_ct")
]
ax.legend(handles=custom_legend, loc="upper right")

# Show the plot
ax.set_xticklabels(df["cuisine"], rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="width: 600px; height: 20px;"></div>

# %% [markdown]
# ### Top 10 Dish Categories in the Database

# %% [markdown]
# The data provided in this analysis sheds light on the most prevalent dish categories within the database. The top 10 categories, including "main_dishes," "starters," and "breakfast," have been aggregated to showcase the most common culinary preferences. Notably, "main_dishes" emerges as the leader with more than 1000 entries, followed by "starters" at around 500. Other categories like "hor d'oeuvre," "snack," "side dish," and "dessert" are also well-represented. This consolidation of similar categories helps uncover valuable insights into the diverse array of dish categories available in the database.

# %%
# listing all dish categories available in the database

r = recipes.aggregate([
    {"$project": { "category":1}},
    {"$unwind": "$category"},
    {"$group": {"_id": "$category", "count": {"$sum": 1}}},
    {"$project": {"_id": 0, "category":1,"name":"$_id", "count":1}},
    {"$sort": {"count": -1}},
    {"$limit": 10}
 ])

pd.DataFrame(r)
# Out:
#    count          name
# 0    273         lunch
# 1    273   main course
# 2    273        dinner
# 3    273     main dish
# 4    127         snack
# 5    127     antipasto
# 6    127     appetizer
# 7    127       starter
# 8    127     antipasti
# 9    127  hor d'oeuvre

# %%
# aggregating similar dish categories available in the database

r = recipes.aggregate([
    {"$project": { "category": 1 }},
    {"$unwind": "$category"},
    {"$group": {
            "_id": {
                "$switch": {
                    "branches": [
                        {"case": { "$in": ["$category", ["dinner", "lunch", "main dish", "main course"]] }, "then": "main_dishes" },
                        {"case": { "$in": ["$category", ["antipasti", "starter", "antipasto", "appetizer", "salad", "soup"]] }, 
                         "then": "starters" },
                        {"case": { "$in": ["$category", ["breakfast", "brunch", "morning meal"]] }, "then": "breakfast" },
                        {"case": { "$in": ["$category", ["drink", "beverage"]] }, "then": "drinks" },
                        {"case": { "$in": ["$category", ["sauce", "seasoning", "marinade", "dip"]] }, "then": "sauces" }],
                    "default": "$category"}},"count": {"$sum": 1}}},
    {"$project": {"_id": 0, "category": 1, "name": "$_id", "count": 1}},
    {"$sort": {"count": -1}}
])

pd.DataFrame(r)
# Out:
#     count          name
# 0    1092   main_dishes
# 1     567      starters
# 2     127         snack
# 3     127  hor d'oeuvre
# 4     123     breakfast
# 5     112     side dish
# 6      85       dessert
# 7      33        sauces
# 8      26     condiment
# 9      26        spread
# 10     18    fingerfood
# 11     18        drinks
# 12      6         bread

# %%
# ploting similar dish categories available in the database

r = recipes.aggregate([
    {"$project": { "category": 1 }},
    {"$unwind": "$category"},
    {"$group": {
            "_id": {
                "$switch": {
                    "branches": [
                        {"case": { "$in": ["$category", ["dinner", "lunch", "main dish", "main course"]] }, "then": "main_dishes" },
                        {"case": { "$in": ["$category", ["antipasti", "starter", "antipasto", "appetizer", "salad", "soup"]] }, 
                         "then": "starters" },
                        {"case": { "$in": ["$category", ["breakfast", "brunch", "morning meal"]] }, "then": "breakfast" },
                        {"case": { "$in": ["$category", ["drink", "beverage"]] }, "then": "drinks" },
                        {"case": { "$in": ["$category", ["sauce", "seasoning", "marinade", "dip"]] }, "then": "sauces" }],
                    "default": "$category"}},"count": {"$sum": 1}}},
    {"$project": {"_id": 0, "category": 1, "name": "$_id", "count": 1}},
    {"$sort": {"count": -1}}
])

df = pd.DataFrame(r)

# Plot a pie chart
ax = df.plot.pie(y='count', labels=df['name'], autopct='%1.1f%%', figsize=(15, 8))
plt.title("Distribution of Similar Dish Categories")
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular.

# Move the legend to the right upper corner
ax.legend(loc='upper right')

plt.show()

# %% [markdown]
# <div style="width: 600px; height: 400px;"></div>

# %% [markdown]
# ### Analysis of Preparation Time

# %% [markdown]
# In our exploration of preparation time data, we first converted minutes to hours to facilitate a more intuitive analysis. We then delved into the 10 recipes with the longest and shortest preparation times, providing a glimpse of extreme cases. Subsequently, we visualized the distribution of recipes by preparation time, removing outliers to focus on the central trends. The data reveals a wide range of preparation times, with the majority falling within the typical cooking timeframe.

# %%
# Showing the 10 recipes with the longest preparation time

r = recipes.aggregate([
    {"$project": {"name": 1, "id": 1, "display_image": 1, "prepTime": 1}},
    {"$addFields": {"prepTimeMinutes": {"$toInt": "$prepTime"}}},
    {"$addFields": {"PrepTimeHours": {"$divide": ["$prepTimeMinutes", 60] }}},
    {"$project": {"_id": 0, "id": 1, "name": 1, "prepTimeMinutes": 1, "PrepTimeHours": 1, "display_image": 1}},
    {"$sort": {"prepTimeMinutes": -1}},
    {"$limit": 5}])
df = pd.DataFrame(r)

# Display the DataFrame with HTML links and images
display(HTML(df.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>display_image</th>
#       <th>prepTimeMinutes</th>
#       <th>PrepTimeHours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>660288</td>
#       <td>Slow Cooker Kahlua Pork with Sweet Chili Pineapple Sauce</td>
#       <td><a href=https://spoonacular.com/recipeImages/660288-556x370.jpg target='_blank'><img src=https://spoonacular.com/recipeImages/660288-556x370.jpg width='150' height='150'></a></td>
#       <td>660</td>
#       <td>11.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>660266</td>
#       <td>Slow Cooked Corned Beef and Cabbage</td>
#       <td><a href=https://spoonacular.com/recipeImages/660266-556x370.jpg target='_blank'><img src=https://spoonacular.com/recipeImages/660266-556x370.jpg width='150' height='150'></a></td>
#       <td>500</td>
#       <td>8.33</td>
# ...

# %%
# Showing the 10 recipes with the shortest preparation time

r = recipes.aggregate([
    {"$project": {"name": 1, "id": 1, "display_image": 1, "prepTime": 1}},
    {"$addFields": {"prepTimeMinutes": {"$toInt": "$prepTime"}}},
    {"$addFields": {"PrepTimeHours": {"$divide": ["$prepTimeMinutes", 60] }}},
    {"$project": {"_id": 0, "id": 1, "name": 1, "prepTimeMinutes": 1, "PrepTimeHours": 1, "display_image": 1}},
    {"$sort": {"prepTimeMinutes": 1}},
    {"$limit": 5}])
df = pd.DataFrame(r)

# Display the DataFrame with HTML links and images
display(HTML(df.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>display_image</th>
#       <th>prepTimeMinutes</th>
#       <th>PrepTimeHours</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1098357</td>
#       <td>Three Ingredient Frozen Pina Colada</td>
#       <td><a href=https://spoonacular.com/recipeImages/1098357-556x370.jpg target='_blank'><img src=https://spoonacular.com/recipeImages/1098357-556x370.jpg width='150' height='150'></a></td>
#       <td>5</td>
#       <td>0.08</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1098355</td>
#       <td>Bahamian Goombay Smash Cocktail</td>
#       <td><a href=https://spoonacular.com/recipeImages/1098355-556x370.jpg target='_blank'><img src=https://spoonacular.com/recipeImages/1098355-556x370.jpg width='150' height='150'></a></td>
#       <td>5</td>
#       <td>0.08</td>
#     </tr>
#     <tr>
# ...

# %%
# Ploting the number of recipes by preparation time (including outliers)

r = recipes.aggregate([
    {"$project": { "prepTime": {"$divide": ["$prepTime", 60]} }},
    {"$group": {"_id": "$prepTime", "count": {"$sum": 1}}},
    {"$project": {"_id": 0, "prepTime": 1, "prepTime": "$_id", "count": 1}},
    {"$sort": {"prepTime": -1}}])

pd.DataFrame(r)
# Out:
#     count  prepTime
# 0       1     11.00
# 1       1      8.33
# 2       1      8.17
# 3       1      8.08
# 4       1      6.67
# ..    ...       ...
# 26      1      0.30
# 27      4      0.25
# 28      1      0.23
# 29      1      0.17
# 30      4      0.08
#
# [31 rows x 2 columns]

# %%
# Ploting the number of recipes by preparation time after removing the outliers (All recipes which take longer than 1.5 h)

r = recipes.aggregate([
    {"$match": {"prepTime": {"$lt": 100}}},
    {"$project": { "prepTime": {"$divide": ["$prepTime", 60]} }},
    {"$group": {"_id": "$prepTime", "count": {"$sum": 1}}},
    {"$project": {"_id": 0, "prepTime": 1, "prepTime": "$_id", "count": 1}},
    {"$sort": {"prepTime": -1}}])

df=pd.DataFrame(r)
df.plot.line(x="prepTime",y="count")
# Out:
# <Axes: xlabel='prepTime'>

# %% [markdown]
# <div style="width: 600px; height: 800px;"></div>

# %% [markdown]
# ##  Conclusion

# %% [markdown]
# In conclusion, our data analysis project provided valuable insights into a diverse collection of recipes. We discovered the top cuisines, ingredients, and equipment used in these recipes, highlighting the rich diversity within the dataset. The exploration of recipe names, source websites, and dietary categories shed light on the unique characteristics of the recipes.
#
# Additionally, our analysis of dish categories offered a broader perspective on the types of dishes people prefer, with "main dishes" and "starters" being the most prevalent. The examination of preparation times revealed the range of cooking durations, from quick recipes to more time-consuming ones.
#
# Overall, this project showcased the versatility and complexity of the culinary world, offering a deeper understanding of the recipes and cooking preferences found within our dataset. These findings can be valuable for culinary enthusiasts, food bloggers, and anyone interested in exploring the world of cooking and recipes.

# %% [markdown]
# ## Learnings

# %% [markdown]
# Through our recipe analysis project, we've uncovered profound insights into the intricate world of cuisine. Our journey of exploring ingredients, cuisines, cooking equipments and international recipes has deepened our understanding of culinary diversity in cooking.
#
# Simultaneously, working with Jupyter Notebook and MongoDB for data analysis has revealed the power of interactive data exploration and the flexibility of handling unstructured data. We have learned to extract data from an API, load it to our data baseand transform it to ensure consistency and data quality.These experiences have highlighted the significance of effective data preprocessing, crafting well-structured aggregations, and maintaining data integrity. Together, they have enriched our knowledge, emphasizing the limitless possibilities in both the culinary and data analysis domains.

# %%
# %%HTML
# <style>
# /* display:none  -> hide In/Out column */
# /* display:block -> show In/Out column */
# div.prompt {display:none}
# h1#Table-of-Contents {display:none}
# </style>
# Out:
# <style>
# /* display:none  -> hide In/Out column */
# /* display:block -> show In/Out column */
# div.prompt {display:none}
# h1#Table-of-Contents {display:none}
# </style>
